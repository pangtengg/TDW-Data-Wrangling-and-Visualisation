# %% [markdown]
# **Data Enrichment**
#
# Description: Two main concepts are covered in this lab:
# 1) data enrichment and
# 2) feature engineering.
# Some of the skills that you have learned are needed to complete the exercises.
#
# In this section, we will use two data sets. One data set is a fake data and another one is the air quality data from UCI (the data set which has be used in lab07 under section Date Time).
#
# 1. Create a fake data with movies title and two users’ profile. The rating with value 1 indicates extremely dislike whereas 10 indicates extremely like.

# %%
import pandas as pd
# create data. In real world, this data may be from database
movies = {'movie_id': [1000, 1001, 1002, 1003],
          'title': ['Toy Story', 'Jumanji', 'Iron Man', 'The Secrets of Dumbledore'],
          'genre': ['Adventure|Animation|Children', 'Adventure|Children|Fantasy', 'Action|Adventure|Sci-Fi', 'Adventure|Fantasy|Family']}

users = {'user_id': [100, 100, 101, 101, 102, 102, 103,103, 103, 104, 104, 105, 
                     106, 106, 106, 107, 107, 108, 108, 109],
         'DOB': [20000221, 20000221, 19901212, 19901212, 19831125, 19831125, 
                 19880920, 19880920, 19880920, 19750614,19750614, 19600522, 19950505, 
                 19950505, 19950505, 19770723, 19770723, 20010101, 20010101, 19990608],
         'movie_id': [1000, 1001, 1000, 1002, 1001,1002, 1000, 1002, 1002, 1001, 1002, 
                      1001, 1000, 1001, 1002, 1001, 1002, 1000, 1001, 1002],
         'timestamp': [20210728, 20210727, 20210726, 20210728, 20210727, 20210726, 20210728, 
                       20210727, 20210726,20210728, 20210727, 20210726, 20210728, 20210727, 20210726,
                       20210728, 20210727, 20210726, 20210727, 20210726],
         'rating': [9,8,7,5,8,7,9,10,5,6,8,8, 9, 8, 6, 8, 7, 8,6,8]}

users1 = {'user_id': [110, 110, 111, 112, 112, 112, 113,113, 113, 114, 114, 115],
         'DOB': [20020202, 20020202, 19901212, 19831130, 19831130, 19831130, 19880905, 
                 19880905, 19880905, 19750610,19750610, 19600512],
         'movie_id': [1000, 1001, 1000, 1002, 1001,1002, 1000, 1002, 1002, 1001, 1002, 1001],
         'timestamp': [20210728, 20210727, 20210726, 20210728, 20210727, 
                       20210726, 20210728, 20210727, 20210726,20210728, 20210727, 20210726],
         'rating': [8,8,9,6,5,8,9,10,8,7,5,8]}

print(movies)
print()
print(users)
print()
print(users1)
# Out:
# {'movie_id': [1000, 1001, 1002, 1003], 'title': ['Toy Story', 'Jumanji', 'Iron Man', 'The Secrets of Dumbledore'], 'genre': ['Adventure|Animation|Children', 'Adventure|Children|Fantasy', 'Action|Adventure|Sci-Fi', 'Adventure|Fantasy|Family']}
#
# {'user_id': [100, 100, 101, 101, 102, 102, 103, 103, 103, 104, 104, 105, 106, 106, 106, 107, 107, 108, 108, 109], 'DOB': [20000221, 20000221, 19901212, 19901212, 19831125, 19831125, 19880920, 19880920, 19880920, 19750614, 19750614, 19600522, 19950505, 19950505, 19950505, 19770723, 19770723, 20010101, 20010101, 19990608], 'movie_id': [1000, 1001, 1000, 1002, 1001, 1002, 1000, 1002, 1002, 1001, 1002, 1001, 1000, 1001, 1002, 1001, 1002, 1000, 1001, 1002], 'timestamp': [20210728, 20210727, 20210726, 20210728, 20210727, 20210726, 20210728, 20210727, 20210726, 20210728, 20210727, 20210726, 20210728, 20210727, 20210726, 20210728, 20210727, 20210726, 20210727, 20210726], 'rating': [9, 8, 7, 5, 8, 7, 9, 10, 5, 6, 8, 8, 9, 8, 6, 8, 7, 8, 6, 8]}
#
# ...

# %% [markdown]
# **Exercise 1: Data Frame and Histogram**
#
# This exercise is to let you practice your python skill in creating data frame and observe the data through histogram.
#
# Perform the following:
#
#     1.1 Now, save both movies, users and users1 into three different data frames named as Data1,
#         Data2 and Data3 respectively.
#
#     1.2 Display the first few rows of each data frame.
#
#     1.3 Explore the feature “rating” by using histogram and set the number of bins = 5. [Hints: the
#         function is .hist(bins=X)]
#
#     1.4 The genre in Data1 is a string, such as “Advanture|Animation|Children”. Change each of the
#         word into a list by manipulating the string.
#
#     1.5 Transform the DOB in Data2 and Data3 from string to date.
#
# **Exercise 2: Adding New Columns**
#
#     2.1 Based on the DOB, count the age of each user in Data2 and Data3.
#     [Hints: to_datetime(‘today’) will get you the date of today but you need only the year]
#
#     2.2 Add the information in Ex2.1 as a new column to Data2 and Data3 respectively.
#     Then, display first few rows of both data.
#
# **Exercise 3: Simple Binning - Assign users to categories 'young', 'middle age', 'senior'**
#
#     3.1) Obtain minAge and maxAge from Data2 through column Age.
#
#     3.2) Set the linspace (linearly spaced values) between minAge and maxAge to 4 intervals. With 4
#     intervals, we can set 3 categories.
#
#     3.3) Use a function called ‘cut’ to have equal width binning.
#
#     3.4) Use qcut and observe the equal frequency binning (approximate). Discuss the differences of
#     output after apply cut and qcut.
#
# **Exercise 4: Clustering and Binning**
#
# Clustering techniques can be used to split the data and are one of the binning techniques.
# A.	In this section, we use k-mean.
#
#     4.1. Import k-mean from sklearn.
#
#     4.2. Create a variable Data4 to store the Age column information in Data2.
#
#     4.3. Set the number of clusters in k-mean to 3 and train on Data4.
#
#     4.4. Add the cluster result from k-mean as an additional columns and name the column as
#     “cluster”.
#
#     4.5. Name the labels by setting 0 as Young, 1 as Middle Age and 2 as Senior.
#
#     4.6. Apply the labels to Data4['cluster'] and add it into Data2 as "class_kmeans"
#
#     4.7. Compare all the other binning results and observe the differences.

# %%
import pandas as pd
import numpy as np

# create data. In real world, this data may be from database
movies = {'movie_id': [1000, 1001, 1002, 1003],
          'title': ['Toy Story', 'Jumanji', 'Iron Man', 'The Secrets of Dumbledore'],
          'genre': ['Adventure|Animation|Children', 'Adventure|Children|Fantasy', 'Action|Adventure|Sci-Fi', 'Adventure|Fantasy|Family']}

users = {'user_id': [100, 100, 101, 101, 102, 102, 103,103, 103, 104, 104, 105, 
                     106, 106, 106, 107, 107, 108, 108, 109],
         'DOB': [20000221, 20000221, 19901212, 19901212, 19831125, 19831125, 
                 19880920, 19880920, 19880920, 19750614,19750614, 19600522, 19950505, 
                 19950505, 19950505, 19770723, 19770723, 20010101, 20010101, 19990608],
         'movie_id': [1000, 1001, 1000, 1002, 1001,1002, 1000, 1002, 1002, 1001, 1002, 
                      1001, 1000, 1001, 1002, 1001, 1002, 1000, 1001, 1002],
         'timestamp': [20210728, 20210727, 20210726, 20210728, 20210727, 20210726, 20210728, 
                       20210727, 20210726,20210728, 20210727, 20210726, 20210728, 20210727, 20210726,
                       20210728, 20210727, 20210726, 20210727, 20210726],
         'rating': [9,8,7,5,8,7,9,10,5,6,8,8, 9, 8, 6, 8, 7, 8,6,8]}

users1 = {'user_id': [110, 110, 111, 112, 112, 112, 113,113, 113, 114, 114, 115],
         'DOB': [20020202, 20020202, 19901212, 19831130, 19831130, 19831130, 19880905, 
                 19880905, 19880905, 19750610,19750610, 19600512],
         'movie_id': [1000, 1001, 1000, 1002, 1001,1002, 1000, 1002, 1002, 1001, 1002, 1001],
         'timestamp': [20210728, 20210727, 20210726, 20210728, 20210727, 
                       20210726, 20210728, 20210727, 20210726,20210728, 20210727, 20210726],
         'rating': [8,8,9,6,5,8,9,10,8,7,5,8]}


#import k-mean, sklearn_cluster


# create data. In real world, this data may be from database



# save both movies, users and users1 into three different data frames named as Data1, Data2 and Data3 respectively. 
print("Exercise 1.1")
Data1 = pd.DataFrame(movies)
Data2 = pd.DataFrame(users)
Data3 = pd.DataFrame(users1)

# Display the first few rows of each data frame. 
print("Exercise 1.2")
# display(Data1.head())
Data1.head()
Data2.head()
Data3.head()

# Explore the feature “rating” by using histogram and set the number of bins = 5. 
# [Hints: the function is .hist(bins=X)]
print("Exercise 1.3")
Data2['rating'].hist(bins=5)
print(Data2)
print()

# The genre in Data1 is a string, such as “Advanture|Animation|Children”. 
# Change each of the word into a list by manipulating the string.
print("Exercise 1.4")
#split the genre column strings at '|' to make lists
Data1.genre = Data1.genre.str.split('|')
display(Data1)

# Transform the DOB in Data2 and Data3 from string to date.
print("Exercise 1.5")
Data2['DOB']=Data2['DOB'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))
Data3['DOB']=Data3['DOB'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))
print(Data2)
print(Data3)
print()
# Out:
# Exercise 1.1
# Exercise 1.2
# Exercise 1.3
#     user_id       DOB  movie_id  timestamp  rating
# 0       100  20000221      1000   20210728       9
# 1       100  20000221      1001   20210727       8
# 2       101  19901212      1000   20210726       7
# 3       101  19901212      1002   20210728       5
# 4       102  19831125      1001   20210727       8
# 5       102  19831125      1002   20210726       7
# 6       103  19880920      1000   20210728       9
# 7       103  19880920      1002   20210727      10
# 8       103  19880920      1002   20210726       5
# 9       104  19750614      1001   20210728       6
# 10      104  19750614      1002   20210727       8
# 11      105  19600522      1001   20210726       8
# 12      106  19950505      1000   20210728       9
# 13      106  19950505      1001   20210727       8
# 14      106  19950505      1002   20210726       6
# 15      107  19770723      1001   20210728       8
# 16      107  19770723      1002   20210727       7
# ...

# %%
# Based on the DOB, count the age of each user in Data2 and Data3. 
# [Hints: to_datetime(‘today’) will get you the date of today but you need only the year]
print("Exercise 2 - Adding New Columns")
print("Exercise 2.1")
Age2 = pd.to_datetime('today').year - Data2['DOB'].dt.year
Age3 = pd.to_datetime('today').year - Data3['DOB'].dt.year

print("Exercise 2.2")
Data2.insert(2, "Age", Age2)
Data3.insert(2, "Age", Age3)
display(Data2.head())
display(Data3.head())
# Out:
# Exercise 2 - Adding New Columns
# Exercise 2.1
# Exercise 2.2
#    user_id        DOB  Age  movie_id  timestamp  rating
# 0      100 2000-02-21   24      1000   20210728       9
# 1      100 2000-02-21   24      1001   20210727       8
# 2      101 1990-12-12   34      1000   20210726       7
# 3      101 1990-12-12   34      1002   20210728       5
# 4      102 1983-11-25   41      1001   20210727       8
#    user_id        DOB  Age  movie_id  timestamp  rating
# 0      110 2002-02-02   22      1000   20210728       8
# 1      110 2002-02-02   22      1001   20210727       8
# 2      111 1990-12-12   34      1000   20210726       9
# 3      112 1983-11-30   41      1002   20210728       6
# 4      112 1983-11-30   41      1001   20210727       5

# %%
import numpy as np
print("Exercise 3 - Simple Binning")
# Obtain minAge and maxAge from Data2 through column Age.
print("Exercise 3.1")
minAge = Data2['Age'].min()
maxAge = Data2['Age'].max()
print(minAge)
print(maxAge)
print()


# Set the linspace (linearly spaced values) between minAge and maxAge to 4 intervals. With 4 
#print("Exercise 3.2")
bins=np.linspace(minAge,maxAge,4)
labels=['young','middle age','senior']


# intervals, we can set 3 categories. 
print("Exercise 3.4")
Data2['bins'] =pd.cut(Data2['Age'], bins=bins, labels=labels, include_lowest=True)
print(Data2)
print()


# 3.3) Use a function called ‘cut’ to have equal width binning. 

# 3.4) Use qcut and observe the equal frequency binning (approximate). Discuss the differences of 
# output after apply cut and qcut.
print("Exercise 3.5")
Data2['bin_qcut'] = pd.qcut(Data2['Age'], q=3, labels=labels, precision=1)
display(Data2)


print("Exercise 4 - Clustering and Binning")
from sklearn.cluster import KMeans

print("Exercise 4.2")
Data4 = Data2[['Age']]
print(Data4)
print()

print("Exercise 4.3")
kmeans = KMeans(n_clusters=3)
kmeans.fit(Data4)
#table plot

print("Exercise 4.4")
Data4.loc[:, 'cluster'] =kmeans.labels_
print(Data4)
print()

print("Exercise 4.5")
labels = {0: "Young", 1: "Middle Age", 2: "Senior"}

print("Exercise 4.6")
Data2["class_kmeans"] = Data4["cluster"].apply(lambda x: labels[x])

print("Exercise 4.7")
print(Data2)
# Out:
# Exercise 3 - Simple Binning
# Exercise 3.1
# 23
# 64
#
# Exercise 3.4
#     user_id        DOB  Age  movie_id  timestamp  rating        bins
# 0       100 2000-02-21   24      1000   20210728       9       young
# 1       100 2000-02-21   24      1001   20210727       8       young
# 2       101 1990-12-12   34      1000   20210726       7       young
# 3       101 1990-12-12   34      1002   20210728       5       young
# 4       102 1983-11-25   41      1001   20210727       8  middle age
# 5       102 1983-11-25   41      1002   20210726       7  middle age
# 6       103 1988-09-20   36      1000   20210728       9       young
# 7       103 1988-09-20   36      1002   20210727      10       young
# 8       103 1988-09-20   36      1002   20210726       5       young
# 9       104 1975-06-14   49      1001   20210728       6  middle age
# 10      104 1975-06-14   49      1002   20210727       8  middle age
# 11      105 1960-05-22   64      1001   20210726       8      senior
# ...

# %% [markdown]
# B.	Another simple clustering technique is **Fisher-Jenks algorithm (natural break)**. The example is demonstrated here.
#
#     1. Install jenkspy if you have not done so
#     2. Import the module and set the break of classes to 3.
#     3. Use function “cut” to break the data according to the break information in
#     Breaks_nature and
#     store the information in a new column ‘bincut_break’. Show the data of this new column by using
#     histogram. Display data.
#
# **Exercise 5 : Concatenate, Merging and Joining**
#
# We can join data frames together to check the intersection/overlapping records between two data sets or combine related information together into one data frame and form a larger data set.
#
#     5.1. Apply a simple concatenate function to combine Data1 and Data2 by columns. Print screen your
#     result and paste in a word document.
#
#     5.2. Add in the parameter join=’inner’. Observe the difference between the output with join and
#     the output in No. 1.
#
#     5.3. The following command is applying merge to combine Data1 and Data2.
#
#     5.4. Use join. to merge Data1 and Data2. Print screen the result. Observe the differences.
#
# **Exercise 6 : Combining the Data**
#
#     6.1. Concatenate Data1 and Data2 by rows. Print screen your result and paste in a word document.
#
#     6.2. Concatenate Data2 and Data3 by columns. Print screen your result and paste in a word
#     document.
#
#     6.3. Concatenate Data2 and Data3 by rows. Print screen your result and paste in a word document.
#
#     6.4. Use join, and change the parameter of how to right, outer and inner. Print the result.
#     Observe the differences among the concatenate results and the join results.
#
# **Exercise 7 : Summarizing/Aggregating**
#
# Summary and aggregation function in Pandas are useful in producing meaningful results.
# Here are some examples:
#
#     7.1. To see the minimum and maximum rating per user and group according to age group (based on
#     the result from function cut in ‘bins’).
#
# **Exercise 8 - Groupby**
#
#     8.1. Check the min and max rating per age group based on the result from qcut (‘bin_qcut’).
#
#     8.2. Check the min and max rating per age group based on the result from k-means
#     (‘class_kmeans’).
#
#     8.3. Display the average rating of each movie.
#
#     8.4. Display the min and max age of user for each movie.
#
#     8.5. Count the number of users for each movie.

# %%
# !pip install jenkspy
# Out:
# ...
#    ---------------------------------------- 0.0/224.6 kB ? eta -:--:--
#    ---------------- ----------------------- 92.2/224.6 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 224.6/224.6 kB 2.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import jenkspy
#import k-mean, sklearn_cluster
from sklearn.cluster import KMeans

# create data. In real world, this data may be from database
print("Exercise 1 - Data Frame and Histogram")
print()
movies = {'movie_id': [1000, 1001, 1002, 1003],
          'title': ['Toy Story', 'Jumanji', 'Iron Man', 'The Secrets of Dumbledore'],
          'genre': ['Adventure|Animation|Children', 'Adventure|Children|Fantasy', 'Action|Adventure|Sci-Fi', 'Adventure|Fantasy|Family']}

users = {'user_id': [100, 100, 101, 101, 102, 102, 103,103, 103, 104, 104, 105, 
                     106, 106, 106, 107, 107, 108, 108, 109],
         'DOB': [20000221, 20000221, 19901212, 19901212, 19831125, 19831125, 
                 19880920, 19880920, 19880920, 19750614,19750614, 19600522, 19950505, 
                 19950505, 19950505, 19770723, 19770723, 20010101, 20010101, 19990608],
         'movie_id': [1000, 1001, 1000, 1002, 1001,1002, 1000, 1002, 1002, 1001, 1002, 
                      1001, 1000, 1001, 1002, 1001, 1002, 1000, 1001, 1002],
         'timestamp': [20210728, 20210727, 20210726, 20210728, 20210727, 20210726, 20210728, 
                       20210727, 20210726,20210728, 20210727, 20210726, 20210728, 20210727, 20210726,
                       20210728, 20210727, 20210726, 20210727, 20210726],
         'rating': [9,8,7,5,8,7,9,10,5,6,8,8, 9, 8, 6, 8, 7, 8,6,8]}



users1 = {'user_id': [110, 110, 111, 112, 112, 112, 113,113, 113, 114, 114, 115],
         'DOB': [20020202, 20020202, 19901212, 19831130, 19831130, 19831130, 19880905, 
                 19880905, 19880905, 19750610,19750610, 19600512],
         'movie_id': [1000, 1001, 1000, 1002, 1001,1002, 1000, 1002, 1002, 1001, 1002, 1001],
         'timestamp': [20210728, 20210727, 20210726, 20210728, 20210727, 
                       20210726, 20210728, 20210727, 20210726,20210728, 20210727, 20210726],
         'rating': [8,8,9,6,5,8,9,10,8,7,5,8]}


Data1 = pd.DataFrame(movies)
Data2 = pd.DataFrame(users)
Data3 = pd.DataFrame(users1)

Data2['rating'].hist(bins=5)
#split the genre column strings at '|' to make lists
Data1.genre = Data1.genre.str.split('|')

Data2['DOB']=Data2['DOB'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))
Data3['DOB']=Data3['DOB'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))

Age2 = pd.to_datetime('today').year- Data2['DOB'].dt.year  
Age3 = pd.to_datetime('today').year- Data3['DOB'].dt.year  

Data2.insert(2,"Age",Age2)
Data3.insert(2,"Age",Age3)

minAge = Data2['Age'].min()
maxAge = Data2['Age'].max()

bins=np.linspace(minAge,maxAge,4)
labels=['young','middle age','senior']

Data2['bins'] =pd.cut(Data2['Age'], bins=bins, labels=labels, include_lowest=True)

Data2['bin_qcut'] = pd.qcut(Data2['Age'], q=3, labels=labels, precision=1)

Data4 = Data2[['Age']]

kmeans = KMeans(n_clusters=3)
kmeans.fit(Data4)

Data4.loc[:, 'cluster'] =kmeans.labels_

labels = {0: "Young", 1: "Middle Age", 2: "Senior"}

Data2["class_kmeans"] = Data4["cluster"].apply(lambda x: labels[x])

#import k-mean, sklearn_cluster
breaks_nature = jenkspy.jenks_breaks(Data2['Age'], 3)

Data2['bincut_break'] = pd.cut(Data2['Age'], bins=breaks_nature, labels=labels, 
                               include_lowest=True)
Data2['bincut_break'].hist()
# Out:
# Exercise 1 - Data Frame and Histogram
# C:\Users\pangt\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\pangt\AppData\Local\Temp\ipykernel_32364\3570861639.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data4.loc[:, 'cluster'] =kmeans.labels_
# <Axes: >

# %%
print("Exercise 5: Concatenate, Merging and Joining")
print("Question 5.1")
print("Concatenate Data1 and Data2 by column")
con1 = pd.concat([Data1, Data2], axis=1)
display(con1) 
print()

print("Question 5.2")
print("Concatenate Data1 and Data2 by column and by join=’inner’")
print("The join data ignore all the NaN and map only the first 4 rows.")
con1 = pd.concat([Data1, Data2], axis=1, join='inner')
display(con1)
print()

print("Question 5.3 - Outer Merge")
outer_Merge = pd.merge(Data1, Data2, how="outer",on='movie_id', suffixes=("_x","_y"))
display(outer_Merge)

print("Question 5.4 - Inner Merge")
inner_Merge = pd.merge(Data1, Data2, how="inner",on='movie_id', suffixes=("_x","_y"))
display(inner_Merge)
print()
# Out:
# Exercise 5: Concatenate, Merging and Joining
# Question 5.1
# Concatenate Data1 and Data2 by column
#     movie_id                      title                             genre  \
# 0     1000.0                  Toy Story  [Adventure, Animation, Children]
# 1     1001.0                    Jumanji    [Adventure, Children, Fantasy]
# 2     1002.0                   Iron Man       [Action, Adventure, Sci-Fi]
# 3     1003.0  The Secrets of Dumbledore      [Adventure, Fantasy, Family]
# 4        NaN                        NaN                               NaN
# 5        NaN                        NaN                               NaN
# 6        NaN                        NaN                               NaN
# 7        NaN                        NaN                               NaN
# 8        NaN                        NaN                               NaN
# 9        NaN                        NaN                               NaN
# ...

# %%
print("Exercise 6: Combining the Data")
print("Question 6.1 - Concatenate Data1 and Data2 by rows.")
con2 = pd.concat([Data1, Data2], axis=0)
display(con2) 
print()

print("Question 6.2 - Concatenate Data2 and Data3 by columns.")
con3 = pd.concat([Data2, Data3], axis=1)
display(con1) 
print()

print("Question 6.3 - Concatenate Data2 and Data3 by rows.")
con4 = pd.concat([Data1, Data2], axis=0)
display(con4) 
print()

print("Question 6.4")

print("Left Join")
result1 = (Data1.set_index("movie_id").join(Data2.set_index("movie_id"),
                                            how="left"))
display(result1)

print("Right Join")
result2 = (Data1.set_index("movie_id").join(Data2.set_index("movie_id"),
                                            how="right"))
display(result2)

print("Outer Join")
result3 = (Data1.set_index("movie_id").join(Data2.set_index("movie_id"),
                                            how="outer"))
display(result3)

print("Inner Join")
result4 = (Data1.set_index("movie_id").join(Data2.set_index("movie_id"),
                                            how="inner"))
display(result4)

print("When combine Data1 and Data2 by column, movie_id in both data are remained.")
print("When it is by row, one of the movie_id is removed.")
print("For Data2 and Data3, as both are users, so the combination are just merging two data together.")
print()

print("Exercise 7 : Summarizing/Aggregating")
print("Question 7.1")
Data2.groupby('user_id').agg({'rating':['min','max']})
Data2.groupby('bins').agg({'rating':['min','max']})
display(Data2)
# Out:
# Exercise 6: Combining the Data
# Question 6.1 - Concatenate Data1 and Data2 by rows.
#     movie_id                      title                             genre  \
# 0       1000                  Toy Story  [Adventure, Animation, Children]
# 1       1001                    Jumanji    [Adventure, Children, Fantasy]
# 2       1002                   Iron Man       [Action, Adventure, Sci-Fi]
# 3       1003  The Secrets of Dumbledore      [Adventure, Fantasy, Family]
# 0       1000                        NaN                               NaN
# 1       1001                        NaN                               NaN
# 2       1000                        NaN                               NaN
# 3       1002                        NaN                               NaN
# 4       1001                        NaN                               NaN
# 5       1002                        NaN                               NaN
# ...

# %%
print("Exercise 8 - Groupby")
print("Question 8.1")
Data2.groupby("bin_qcut").agg({'rating':['min','max']})
display(Data2)

print("Question 8.2")
Data2.groupby("class_kmeans").agg({'rating':['min','max']})
display(Data2)

print("Question 8.3")
Data2.groupby("movie_id").agg({'rating':['mean']})
display(Data2)

print("Question 8.4")
Data2.groupby("movie_id").agg({'Age':['min','max']})
display(Data2)

print("Question 8.5")
Data2.groupby("movie_id").agg({'user_id':['count']})
display(Data2)
# Out:
# Exercise 8 - Groupby
# Question 8.1
# C:\Users\pangt\AppData\Local\Temp\ipykernel_32364\438431816.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Data2.groupby("bin_qcut").agg({'rating':['min','max']})
#     user_id        DOB  Age  movie_id  timestamp  rating        bins  \
# 0       100 2000-02-21   24      1000   20210728       9       young
# 1       100 2000-02-21   24      1001   20210727       8       young
# 2       101 1990-12-12   34      1000   20210726       7       young
# 3       101 1990-12-12   34      1002   20210728       5       young
# 4       102 1983-11-25   41      1001   20210727       8  middle age
# 5       102 1983-11-25   41      1002   20210726       7  middle age
# 6       103 1988-09-20   36      1000   20210728       9       young
# ...

# %% [markdown]
# **Exercise 9 : Resampling**
#
# In this section, the air quality data is used. You can reuse the command where we have converted date time into the proper data type.
#
# The features of this data are as below:
#
# 0 Date (DD/MM/YYYY)
# 1 Time (HH.MM.SS)
# 2 True hourly averaged concentration CO in mg/m^3 (reference analyzer)
# 3 PT08.S1 (tin oxide) hourly averaged sensor response (nominally CO targeted)
# 4 True hourly averaged overall Non Metanic HydroCarbons concentration in microg/m^3 (reference analyzer)
# 5 True hourly averaged Benzene concentration in microg/m^3 (reference analyzer)
# 6 PT08.S2 (titania) hourly averaged sensor response (nominally NMHC targeted)
# 7 True hourly averaged NOx concentration in ppb (reference analyzer)
# 8 PT08.S3 (tungsten oxide) hourly averaged sensor response (nominally NOx targeted)
# 9 True hourly averaged NO2 concentration in microg/m^3 (reference analyzer)
# 10 PT08.S4 (tungsten oxide) hourly averaged sensor response (nominally NO2 targeted)
# 11 PT08.S5 (indium oxide) hourly averaged sensor response (nominally O3 targeted)
# 12 Temperature in Â°C
# 13 Relative Humidity (%)
# 14 AH Absolute Humidity
#
# **Questions**
#
# 1. Set the date as index and display the first few rows of the data.
#
# 2. Resample the data by producing average value by week. This is called downsample.
#
# 3. Produce the min and max value by week. Note that there are some values are NaN.
#
# 4. Upsampling: Produce the average value by 30 minutes and forward fill the values

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("AirQualityUCI.csv", header=[0], sep=";")
#this portion handle the missing data
threshold=data.isnull().sum()/ len(data) 
#print(threshold)
remove_col = threshold[threshold>0.8].index #get the index of each columns and store in remove_col
data.drop(remove_col, axis=1, inplace = True)
#print(data.columns)
threshold = data.isnull().sum(axis=1)/(len(data.columns)-1)
#print(threshold)
remove_row = threshold[threshold>0.8].index
data.drop(remove_row, axis=0, inplace = True)
print(data.head()) #check to make sure it moves only those with missing values >80%
print(len(data))
data['Date'] = pd.to_datetime(data['Date'])
data['Time'] = pd.to_datetime(data['Time'], format = '%H.%M.%S').dt.time

print("Question 1")
data1=data.set_index(pd.DatetimeIndex(data['Date'])).drop("Date", axis=1)
data1.head()
print()

print("Question 2")
data1.resample("W").mean().ffill()
print(data1)
print()

print("Question 3")
data1.resample("W").agg(['min','max'])
print(data1)
print()

print("Question 4")
data1.resample("30min").mean().ffill()
print(data1)
print()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH
# 0  0,7578
# 1  0,7255
# 2  0,7502
# 3  0,7867
# ...

# %%
conda install -c conda-forge mlxtend
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.14.0
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda

# %% [markdown]
# **Exercise 10 : Feature Selection**
#
# In this section, use the data from https://archive.ics.uci.edu/ml/datasets/Real+estate+valuation+data+set
#
# Here is the information about the data:
#
# The market historical data set of real estate valuation are collected from Sindian Dist., New Taipei City, Taiwan. The real estate valuation is a regression problem. The data set was randomly split into the training data set (2/3 samples) and the testing data set (1/3 samples).
#
# Attribute Information:
# The inputs are as follows:
#
# X1=the transaction date (for example, 2013.250=2013 March, 2013.500=2013 June, etc.) X2=the house age (unit: year)
# X3=the distance to the nearest MRT station (unit: meter)
# X4=the number of convenience stores in the living circle on foot (integer)
# X5=the geographic coordinate, latitude. (unit: degree)
# X6=the geographic coordinate, longitude. (unit: degree)
#
# The output is as follow:
#
# Y= house price of unit area (10000 New Taiwan Dollar/Ping, where Ping is a local unit, 1 Ping = 3.3 meter squared)
#
# **Questions 1 - Correlation and heatmap**
#
#     1.1. Import all the modules and data.
#
#     1.2. Drop the first columns which contains only numbers.
#
#     1.3. Produce correlation matrix.
#
#     1.4. Produce the heat map. Based on 3 and 4,
#     a.	Identify the positive and negative correlated variables.
#     b.	Identify variables that have very low correlation.
#
#     1.5. The dependent variable is Y, thus we only interest to know which variables are meaningful to
#        determine Y. Let us set the correlation threshold as 0.5. When the features are having
#        correlation    +-0.5 and above, then the features are selected.
#
# **Questions 2 - Variance Inflation Factor (VIF)**
#
#     2.1  Import VIF
#
#     2.2  Declare x (independent variables) and y (dependent variable)
#
#     2.3  Run VIF directly and observe the result
#
#     2.4  Then, try to run multiple regression and generate the VIF. Now, observe the result.
#     Which features should be selected?
#
# **Questions 3 - Wrapper Method (Forward Selection)**
#
#     3.1  Import modules
#
#     3.2  Build linear regression model to use in feature selection
#
#     3.3  Build step forward feature selection
#
#     3.4  Perform step forward feature selection
#
#     3.5  In this command, we use random forest to select useful features.
#     Which features are selected?
#
#
# **Questions 4 - Wrapper Method (Backward Elimination)**
#
#     4.1  Use linear regression to perform backward elimination.
#          Which features are selected?
#
# **Questions 5 - Embedded Method**
#
#     5.1  Use Lasso Regression method. Which features are selected?

# %%
#import all the modules and data
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score as acc
from mlxtend.feature_selection import SequentialFeatureSelector as sfs


#import VIF
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from mlxtend.feature_selection import SequentialFeatureSelector 
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LassoCV

np.random.seed(123)
data = pd.read_excel('Real estate valuation data set.xlsx')
print(data.head())

print("Questions 1 - Correlation and heatmap")
print("Question 1.2")
data = data.iloc[:,1:8]
print(data.head())
print()

print("Question 1.3")
cor = data.corr()
cor
print()

#print("Question 1.4")
#plt.figure(figsize=(10,6))
#sns.heatmap(cor, annot=True)
#print()

print("Question 1.5")
threshold = 0.5
s = abs(cor['Y house price of unit area'])
selectedFeature = s[s>0.5]
print(selectedFeature)
print()

print("Questions 2 - Variance Inflation Factor (VIF)")
print("Question 2.2")
x = data.iloc[:,0:6] #0 to 5, need to set as 0:6
y = data.iloc[:, 6]
print(x.head())
print(y.head())
print()

print("Question 2.3")
vif=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
print(vif)
print()

print("Question 2.4")
#run regression and generate VIF
Reg = sm.OLS(y, x).fit() #OLS = ordinary linear squares regression model
pd.DataFrame({'variables': x.columns[0:6], 'VIF':[variance_inflation_factor(x.values, i) 
                                                  for i in range(len(x.columns[0:6]))]})

print("Feature 1, 2, 3, 4 and 6. 5 considers too high compare to the other features. ")
print()

print("Questions 3 - Wrapper Method (Forward Selection)")
print("Question 3.3")
LR = LinearRegression()
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

print("Question 3.4")
step_forward = sfs(LR, k_features = 4, forward = True, floating = False, 
                   scoring = 'r2', verbose = 2, cv = 5)

#print("Question 3.5")
step_forward = step_forward.fit(X_train, Y_train)
print(list(step_forward.k_feature_idx_))

#print("Question 3.5")
feature_selector = SequentialFeatureSelector(RandomForestRegressor(random_state=0), k_features = 4, forward = True, floating = False, 
                                             scoring = 'r2', verbose = 2, cv = 5)

features=feature_selector.fit(X_train, Y_train)
print(list(features.k_feature_idx_))

f_i = list(zip(data,rf.feature_importances_))
f_i.sort(key = lambda x : x[1])
plt.barh([x[0] for x in f_i],[x[1] for x in f_i])

plt.show()

print("Question 4.1")
cols=list(x.columns) #get the columns
while(len(cols)>0):  #when there are columns available in cols
    p=[]
    x_1=x[cols]
    x_1=sm.add_constant(x_1)
    model=sm.OLS(y,x_1).fit() 
    #sm is an object of stat models, and we use OLS froms statmodels library
    p=pd.Series(model.pvalues.values[1:], index=cols)
    pmax=max(p)
    features_with_p_max=p.idxmax()
    if(pmax>0.05):  #p is the null hypothesis p value, if greater than 0.05, remove feature
        cols.remove(features_with_p_max)
    else:
        break
    summary = model.summary()

print(summary)
selected_features=cols
print(selected_features)

#Solution should display X1, X2, X3, X4, X5

print("Question 5.1")
reg = LassoCV()
reg.fit(x,y)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" %reg.score(x,y))
coef=pd.Series(reg.coef_, index=x.columns)
print(coef)

print("Lasso picked " + str(sum(coef != 0))+"variables and eliminated the other " + str(sum(coef == 0)) + " variables")
imp_coef = coef.sort_values()
import matplotlib
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Feature importance using Lasso Model")

print("Solution is X2 and X3")
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1          2012.916667          32.0
# 1   2          2012.916667          19.5
# 2   3          2013.583333          13.3
# 3   4          2013.500000          13.3
# 4   5          2012.833333           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %% [markdown]
# **Exercise 5 : Feature Selection**
#
#     5.1 Download breast cancer data set from this link:
#     https://archive.ics.uci.edu/ml/datasets/breast+cancer+wisconsin+(diagnostic)
#     Hints: you can refer to lab 7 to use a ready data set by impute the missing data with median.
#
#     5.2 Perform feature selection as below:
#     a.	applies a forward selection by using linear regression, set k_features = 4. Record the
#     selected features.
#
#     b.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score as acc
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression

from sklearn.linear_model import LassoCV
import matplotlib.pyplot as plt

print("Question 5.1")
data = pd.read_csv("breast-cancer-wiconsin.data", sep=",", header=None)
data.columns = ["ID", "Clump_Thickness", "Uniformity_CellShape", "Uniformity_CellShape", "Marginal_Adhesion", 
                "Single_Epithelial", "Bare_Nuclei", "Bland_Chromatin", "Normal_Nucleoli", "Mitoses", "Classes"]
print(data.isnull().sum())
data = data.replace('?',np.NaN)
# check num of missing values
for col in data.columns:
    print('\t%s: %d' % (col,data[col].isna().sum()))
# impute using median
data.Bare_Nuclei.fillna(data.Bare_Nuclei.median(), inplace=True)
print(data.Bare_Nuclei.isna().sum())
x = data.loc[:,1:10] #ignore column ID

print("Question 5.2(a)")
LR = LinearRegression()
X_train, X_test, Y_train, Y_test = train_test_split(x, t, test_size=0.3, random_state=)
step_forward = step_forward.fit(X_train, Y_train)
print(list(step_forward.k_feature_idx_))
print()

 
print("Question 5.2(b)")
cor = data.corr()

threhold = 0.5
s = abs(cor['Classes'])
selectedFeature = s[s>0.5]
print(selectedFeature)
print()


print("Question 5.2(c)")
reg = LassoCV()
reg.fit(x,y)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" % reg.score(x,y))
coef=pd.Series(reg.coef_, index=x.columns)
print(coef)
print("Lasso picked "  + str(sum(coef != 0))+"variables and eliminated the other " + str(sum(coef == 0)) + " vari
print()
      
#the plot figure below shows which features are selected
imp_coef = coef.sort_values()
import matplotlib
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Feature importance using Lasso Model")
